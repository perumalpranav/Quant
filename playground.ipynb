# %%
#!pip install -q yfinance pandas backtrader matplotlib scikit-learn mplfinance
#All required libraries

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
import backtrader as bt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import mplfinance as mpf

# %%
symbol = 'AAPL'
start_date = '2020-01-01'
end_date = '2023-12-31'

data = yf.download(symbol, start=start_date, end=end_date)[['Open', 'High', 'Low', 'Close', 'Volume']]
data.dropna(inplace=True)
data.columns = ['open', 'high', 'low', 'close', 'volume']
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  open       high        low      close     volume
# Date
# 2020-01-02  71.344054  72.394086  71.091184  72.333878  135480400
# 2020-01-03  71.563228  72.389280  71.406689  71.630661  146322800
# 2020-01-06  70.754014  72.239942  70.503546  72.201408  118387200
# 2020-01-07  72.211033  72.466315  71.642674  71.861832  108872000
# 2020-01-08  71.565629  73.318885  71.565629  73.017845  132079200
